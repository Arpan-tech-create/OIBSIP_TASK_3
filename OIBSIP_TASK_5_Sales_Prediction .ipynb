# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')
plt.rcParams['figure.figsize']=(15,10)
plt.rcParams['font.size']=15

# %%
raw=pd.read_csv('Advertising.csv')
raw
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
raw.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
sns.pairplot(raw,x_vars=['TV','Radio','Newspaper'],y_vars=['TV','Radio','Newspaper'])
plt.show()

# %%
x=raw[['TV','Radio','Newspaper']]

# %%
y=raw['Sales']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
x_train
# Out:
#         TV  Radio  Newspaper
# 165  234.5    3.4       84.8
# 12    23.8   35.1       65.9
# 77   120.5   28.5       14.2
# 80    76.4   26.7       22.3
# 59   210.7   29.5        9.3
# ..     ...    ...        ...
# 198  283.6   42.0       66.2
# 149   44.7   25.8       20.6
# 69   216.8   43.9       27.2
# 175  276.9   48.9       41.8
# 11   214.7   24.0        4.0
#
# [160 rows x 3 columns]

# %%
x_test
# Out:
#         TV  Radio  Newspaper
# 51   100.4    9.6        3.6
# 178  276.7    2.3       23.7
# 176  248.4   30.2       20.3
# 186  139.5    2.1       26.6
# 173  168.4    7.1       12.8
# 170   50.0   11.6       18.4
# 61   261.3   42.7       54.7
# 158   11.7   36.9       45.2
# 8      8.6    2.1        1.0
# 78     5.4   29.9        9.4
# 199  232.1    8.6        8.7
# 34    95.7    1.4        7.4
# 74   213.4   24.6       13.1
# 110  225.8    8.2       56.5
# 91    28.6    1.5       33.0
# 131  265.2    2.9       43.0
# 47   239.9   41.5       18.5
# 192   17.2    4.1       31.6
# 193  166.8   42.0        3.6
# 9    199.8    2.6       21.2
# 65    69.0    9.3        0.9
# 127   80.2    0.0        9.2
# 117   76.4    0.8       14.8
# 164  117.2   14.7        5.4
# 197  177.0    9.3        6.4
# 104  238.2   34.3        5.3
# 94   107.4   14.0       10.9
# 145  140.3    1.9        9.0
# 42   293.6   27.7        1.8
# 40   202.5   22.3       31.6
# 87   110.7   40.6       63.2
# 88    88.3   25.5       73.4
# 63   102.7   29.6        8.4
# 141  193.7   35.4       75.6
# 84   213.5   43.0       33.8
# 56     7.3   28.1       41.4
# 123  123.1   34.6       12.4
# 152  197.6   23.3       14.2
# 115   75.1   35.0       52.7
# 163  163.5   36.8        7.4

# %%
y_train
# Out:
# 165    11.9
# 12      9.2
# 77     14.2
# 80     11.8
# 59     18.4
#        ...
# 198    25.5
# 149    10.1
# 69     22.3
# 175    27.0
# 11     17.4
# Name: Sales, Length: 160, dtype: float64

# %%
y_test
# Out:
# 51     10.7
# 178    11.8
# 176    20.2
# 186    10.3
# 173    11.7
# 170     8.4
# 61     24.2
# 158     7.3
# 8       4.8
# 78      5.3
# 199    13.4
# 34      9.5
# 74     17.0
# 110    13.4
# 91      7.3
# 131    12.7
# 47     23.2
# 192     5.9
# 193    19.6
# 9      10.6
# 65      9.3
# 127     8.8
# 117     9.4
# 164    11.9
# 197    12.8
# 104    20.7
# 94     11.5
# 145    10.3
# 42     20.7
# 40     16.6
# 87     16.0
# 88     12.9
# 63     14.0
# 141    19.2
# 84     21.7
# 56      5.5
# 123    15.2
# 152    16.6
# 115    12.6
# 163    18.0
# Name: Sales, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_pred
# Out:
# array([ 9.16993552, 16.04998166, 20.00881138,  9.6137978 , 11.88591875,
#         7.22222809, 23.03853796, 10.27410922,  3.46015509,  8.59193717,
#        15.13595274,  7.40371273, 17.30194393, 14.84896089,  4.33535822,
#        15.66036577, 21.74971669,  4.293436  , 18.40694319, 12.51345141,
#         7.64294137,  6.41820097,  6.40210806, 10.92330466, 12.69298411,
#        20.28349993, 10.34284212,  9.5827529 , 21.61269435, 16.38955371,
#        15.62671343, 11.73832278, 13.0745005 , 18.53681008, 20.82826707,
#         8.39505329, 14.98075387, 16.32016247, 12.88612568, 17.27439606])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8889831936014705

# %% [markdown]
# # 88% Accuracy

# %%
plt.scatter(y_test,y_pred)
plt.show()
